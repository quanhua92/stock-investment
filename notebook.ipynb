# %%
import os
if "ACCEPT_TC" not in os.environ:
    os.environ["ACCEPT_TC"] = "tôi đồng ý"

from vnstock3 import Vnstock
from datetime import datetime
import matplotlib.pyplot as plt

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
MY_ID_MAPPING = {
    # "BTC": "c2111",
    # "ETH": "c2112",
    # "USDT": "c2115",
    # "USDC": "c211a", 
    # "BNB": "c2113",
    # "BUSD": "c211i",
    # "XRP": "c2117",
    # "ADA": "c2114",
    # "SOL": "c2116",
    # "DOGE": "c2119",

    "TON": "c23br",
    
    "SPX": "a33k6h",
    "DJI": "a6qja2",
    "GOLD": "b1hb7w",
    "NDX":"a3yy77",
    "VNI": "aqk2nm",
    "JAPAN": "c1uvw7",
    "NYSE": "a74pqh",
    
    "USDEUR": "avyn9c",
    "USDVND": "avyufr",
    "JPYVND": "ave8sm",
    "AUDVND": "auxrkr",
    "EURVND": "av93ec",
    "GBPVND": "avyjtc",
}

# %%
# index = Vnstock().world_index(source='MSN')
# df = index.quote.history(start='2023-01-01', end='2024-12-31', interval='1D', symbol="GOLD")
# df
from vnstock3.explorer.msn.quote import *
fx = Quote(symbol_id='c23br')
btc = fx.history(start='2024-01-01', end='2024-12-31', interval='1D')
btc
# Out:
#           time       open       high        low      close         volume
# 0   2024-01-02   58730.37   59869.18   58323.65   59401.46   899198642593
# 1   2024-01-03   59406.54   61735.01   57972.85   58125.37  1520221250747
# 2   2024-01-04   58127.91   58580.39   52646.32   56300.22  1940617771512
# 3   2024-01-05   56302.76   57200.08   54190.36   55209.70  1506953074066
# 4   2024-01-06   55209.70   56140.07   52747.54   53041.88  1819020565758
# ..         ...        ...        ...        ...        ...            ...
# 149 2024-05-30  164297.09  167118.71  163102.35  165036.81  4321095694892
# 150 2024-05-31  165036.81  166526.42  161167.88  164663.13  4233121811655
# 151 2024-06-01  164368.26  164696.18  160819.63  161101.79  3572759042458
# 152 2024-06-02  161101.79  161772.88  159375.77  159802.83  3243343705828
# 153 2024-06-03  159802.83  177284.16  159596.93  173321.19  9589170810875
#
# [154 rows x 6 columns]

# %%
configs = {
    "INDEX": ["SPX", "DJI", "GOLD", "NDX", "VNI", "JAPAN", "NYSE"],
    # "CRYPTO": ["BTC", "ETH", "USDT", "USDC", "BNB", "BUSD", "XRP", "ADA", "SOL", "DOGE"],
    "FOREX": ["USDEUR", "USDVND", "JPYVND", "AUDVND", "EURVND", "GBPVND"]
}

# %%
def is_stock_group(name):
    return name not in ["INDEX", "CRYPTO", "FOREX"]

# %%
for group_name, tickers in configs.items():
    print(group_name, is_stock_group(group_name))
    for ticker in tickers:
        print(ticker, MY_ID_MAPPING[ticker])
# Out:
# INDEX False
# SPX a33k6h
# DJI a6qja2
# GOLD b1hb7w
# NDX a3yy77
# VNI aqk2nm
# JAPAN c1uvw7
# NYSE a74pqh
# FOREX False
# USDEUR avyn9c
# USDVND avyufr
# JPYVND ave8sm
# AUDVND auxrkr
# EURVND av93ec
# GBPVND avyjtc

# %%
crypto = Vnstock().crypto(symbol='BTC', source='MSN')
df = crypto.quote.history(start='2023-01-01', end='2024-12-31', interval='1D')
df
# Out:
#           time          open          high           low         close  \
# 151 2023-01-07  4.279832e+08  4.319365e+08  4.249315e+08  4.309191e+08
# 152 2023-02-06  5.931057e+08  5.954237e+08  5.806375e+08  5.835330e+08
# 153 2023-03-08  5.701280e+08  5.726470e+08  5.595263e+08  5.648265e+08
# 154 2023-04-07  7.162143e+08  7.162945e+08  7.051193e+08  7.128820e+08
# 155 2023-05-07  7.508778e+08  7.580276e+08  7.236812e+08  7.347555e+08
# 156 2023-06-06  6.894695e+08  6.896442e+08  6.468162e+08  6.548217e+08
# 157 2023-07-06  7.823952e+08  7.849017e+08  7.683351e+08  7.756701e+08
# 158 2023-08-05  7.416128e+08  7.448588e+08  7.342652e+08  7.390634e+08
# 159 2023-09-04  6.576020e+08  6.631353e+08  6.562689e+08  6.601464e+08
# 160 2023-10-04  6.992598e+08  7.033000e+08  6.918308e+08  6.972701e+08
# 161 2023-11-03  9.009249e+08  9.130824e+08  8.744880e+08  8.881301e+08
# 162 2023-12-03  9.834815e+08  1.008639e+09  9.825490e+08  1.003488e+09
# 163 2024-01-02  1.074764e+09  1.122940e+09  1.073105e+09  1.122734e+09
# 164 2024-02-01  1.091694e+09  1.111296e+09  1.075239e+09  1.082450e+09
# 165 2024-03-02  1.554892e+09  1.605403e+09  1.545600e+09  1.587241e+09
# 166 2024-04-01  1.770447e+09  1.814423e+09  1.769864e+09  1.813301e+09
# 167 2024-05-01  1.622798e+09  1.644759e+09  1.502832e+09  1.541389e+09
# 168 2024-05-31  1.717784e+09  1.766704e+09  1.706142e+09  1.737838e+09
#
#                volume
# 151   366395311241342
# 152   497323555424438
# 153   578697795024917
# 154   351757114446717
# 155   404530491881827
# 156   546867899073521
# 157   317282838346161
# 158   305971388485300
# 159   227827373374405
# 160   289986636623117
# 161   533773190194326
# 162   394875185255514
# 163   468413792027415
# 164   627203643922127
# 165  1021537485311388
# 166   509694929697338
# 167   961914154254278
# 168   750136892608941

# %%
stock = Vnstock().stock(source='VCI')
# Out:
# 2024-06-03 04:16:19,838 - vnstock3.common.vnstock - INFO - Mã chứng khoán không được chỉ định, chương trình mặc định sử dụng VN30F1M
# 2024-06-03 04:16:19,841 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS

# %%
from vnstock3 import Vnstock
fx = Vnstock().fx(source='MSN')
df = fx.quote.history(symbol='NDX', start='2024-02-28', end='2024-05-25', interval='1D')
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 3
#       1 from vnstock3 import Vnstock
#       2 fx = Vnstock().fx(source='MSN')
# ----> 3 df = fx.quote.history(symbol='NDX', start='2024-02-28', end='2024-05-25', interval='1D')
#       4 df
#
# File ~/workspace/stock-investment/.env/stock/lib/python3.11/site-packages/vnstock3/common/data/data_explorer.py:96, in Quote.history(self, symbol, **kwargs)
#      94 symbol_map = {**_CURRENCY_ID_MAP, **_GLOBAL_INDICES, **_CRYPTO_ID_MAP}
#      95 if symbol:
# ---> 96     self.symbol = symbol_map[symbol]
#      97     logger.info(f"Chuyển đổi mã chứng khoán {symbol} sang mã chứng khoán MSN: {self.symbol}")
#      98     self._update_data_source(symbol=self.symbol)
#
# KeyError: 'NDX'

# %%
from vnstock3.explorer.misc.gold_price import *

sjc_gold_price()
# Out:
# Cập nhật lúc: 02:29:23 PM 03/06/2024
# Đơn vị tính: Đơn vị tính: VNĐ/lượng
#                                                 name   buy_price  sell_price
# 0                                   SJC 1L, 10L, 1KG  77,980,000  79,980,000
# 1                                             SJC 5c  77,980,000  80,000,000
# 2                                 SJC 2c, 1C, 5 phân  77,980,000  80,010,000
# 3          Vàng nhẫn SJC 99,99 | 1 chỉ, 2 chỉ, 5 chỉ  73,400,000  75,000,000
# 4  Vàng nhẫn SJC 99,99 | 0.3 chỉ,  0.5 chỉ73,400,...  73,400,000  75,100,000
# 5                                    Nữ Trang 99.99%  73,200,000  74,200,000
# 6                                       Nữ Trang 99%  71,465,000  73,465,000
# 7                                       Nữ Trang 68%  48,111,000  50,611,000
# 8                                     Nữ Trang 41.7%  28,594,000  31,094,000

# %%
from vnstock3.explorer.msn.listing import Listing
Listing(api_version='20240530').search_symbol_id('OIL')
# Out:
#    symbol symbol_id exchange_name  exchange_code_mic  \
# 0     OIL    ahj9cw           NSE               XNSE
# 1     OIL    bnmrww     Bucharest               XBSE
# 2     OIL    alxgqh     Bucharest               XBSE
# 3     OIL    aa8dr7     Australia               XASX
# 4     OIL    b115z2        Canada               XCNQ
# 5     OIL    bomeim         Paris               XPAR
# 6     OIL    bomefr         Milan               XMIL
# 7  OILUIV    bkj2m7                     INDX_DEFAULT
# 8  OILDIV    bkj2jc                     INDX_DEFAULT
# 9  OILKIV    c89xxm                INDX_DEFAULT-CBOE
#
#                                      short_name  \
# 0                                     Oil India
# 1                                  Oil Terminal
# 2                                  Oil Terminal
# 3                              Optiscan Imaging
# 4                              Permex Petroleum
# 5                AmundiSTOXXEuro600EnESGScrETFA
# 6                AmundiSTOXXEuro600EnESGScrETFA
# 7    AccuShares S&P GSCI Crude Oil ER Up Shares
# 8  AccuShares S&P GSCI Crude Oil ER Down Shares
# 9     PROSHARES K-1 FREE CRUDE OIL STRATEGY ETF
#
#                                   friendly_name  \
# 0                                     Oil India
# 1                                  Oil Terminal
# 2                                  Oil Terminal
# 3                              Optiscan Imaging
# 4                              Permex Petroleum
# 5                AmundiSTOXXEuro600EnESGScrETFA
# 6                AmundiSTOXXEuro600EnESGScrETFA
# 7    AccuShares S&P GSCI Crude Oil ER Up Shares
# 8  AccuShares S&P GSCI Crude Oil ER Down Shares
# 9     PROSHARES K-1 FREE CRUDE OIL STRATEGY ETF
#
#                                             eng_name  \
# 0                                      Oil India Ltd
# 1                                    Oil Terminal SA
# 2                                    Oil Terminal SA
# 3                               Optiscan Imaging Ltd
# 4                              Permex Petroleum Corp
# 5  Amundi STOXX Euro 600 Engy ESG Scrnd UCITS ETF...
# 6  Amundi STOXX Euro 600 Engy ESG Scrnd UCITS ETF...
# 7         AccuShares S&P GSCI Crude Oil ER Up Shares
# 8       AccuShares S&P GSCI Crude Oil ER Down Shares
# 9          PROSHARES K-1 FREE CRUDE OIL STRATEGY ETF
#
#                                          description  \
# 0  Oil India Limited is an India-based integrated...
# 1  Oil Terminal SA is a Romania-based company pri...
# 2  Oil Terminal SA is a Romania-based company pri...
# 3  Optiscan Imaging Limited is an Australia-based...
# 4  Permex Petroleum Corporation is a junior oil a...
# 5
# 6
# 7
# 8
# 9
#
#                                           local_name locale
# 0                                      Oil India Ltd  en-in
# 1                                    Oil Terminal SA  ro-ro
# 2                                    Oil Terminal SA  ro-ro
# 3                               Optiscan Imaging Ltd  en-au
# 4                              Permex Petroleum Corp  en-ca
# 5  Amundi STOXX Euro 600 Engy ESG Scrnd UCITS ETF...  fr-fr
# 6  Amundi STOXX Euro 600 Engy ESG Scrnd UCITS ETF...  it-it
# 7         AccuShares S&P GSCI Crude Oil ER Up Shares  en-us
# 8       AccuShares S&P GSCI Crude Oil ER Down Shares  en-us
# 9          PROSHARES K-1 FREE CRUDE OIL STRATEGY ETF  en-us

# %%
# index = Vnstock().world_index(source='MSN')
# df = index.quote.history(start='2023-01-01', end='2024-12-31', interval='1D', symbol="GOLD")
# df
from vnstock3.explorer.msn.quote import *
fx = Quote(symbol_id='c23br')
btc = fx.history(start='2023-01-01', end='2024-12-31')
btc
# Out:
#           time       open       high        low      close         volume
# 0   2023-06-05   44322.31   44645.15   44141.83   44502.79   186098217269
# 1   2023-06-06   44515.50   44563.80   41955.71   42225.16   298852199795
# 2   2023-06-07   42225.16   42631.88   42001.47   42542.91   276610667535
# 3   2023-06-08   42525.12   42555.62   41505.78   41637.96   238972335582
# 4   2023-06-09   41620.17   42842.87   41546.45   42553.08   176119763024
# ..         ...        ...        ...        ...        ...            ...
# 360 2024-05-30  164297.09  167118.71  163102.35  165036.81  4321095694892
# 361 2024-05-31  165036.81  166526.42  161167.88  164663.13  4233121811655
# 362 2024-06-01  164368.26  164696.18  160819.63  161101.79  3572759042458
# 363 2024-06-02  161101.79  161772.88  159375.77  159802.83  3243343705828
# 364 2024-06-03  159802.83  177284.16  159596.93  173321.19  9589170810875
#
# [365 rows x 6 columns]

# %%
len(btc)
# Out:
# 18

# %%
btc
# Out:
#           time          open          high           low         close  \
# 151 2023-01-07  4.276969e+08  4.316476e+08  4.246473e+08  4.306309e+08
# 152 2023-02-06  5.927091e+08  5.950255e+08  5.802492e+08  5.831428e+08
# 153 2023-03-08  5.697467e+08  5.722640e+08  5.591521e+08  5.644488e+08
# 154 2023-04-07  7.157353e+08  7.158155e+08  7.046477e+08  7.124053e+08
# 155 2023-05-07  7.503756e+08  7.575207e+08  7.231972e+08  7.342642e+08
# 156 2023-06-06  6.890084e+08  6.891829e+08  6.463836e+08  6.543837e+08
# 157 2023-07-06  7.818720e+08  7.843768e+08  7.678212e+08  7.751514e+08
# 158 2023-08-05  7.411168e+08  7.443607e+08  7.337742e+08  7.385692e+08
# 159 2023-09-04  6.571622e+08  6.626919e+08  6.558301e+08  6.597049e+08
# 160 2023-10-04  6.987921e+08  7.028297e+08  6.913681e+08  6.968038e+08
# 161 2023-11-03  9.003224e+08  9.124718e+08  8.739032e+08  8.875362e+08
# 162 2023-12-03  9.828237e+08  1.007964e+09  9.818919e+08  1.002817e+09
# 163 2024-01-02  1.074045e+09  1.122189e+09  1.072387e+09  1.121983e+09
# 164 2024-02-01  1.090964e+09  1.110553e+09  1.074520e+09  1.081726e+09
# 165 2024-03-02  1.553852e+09  1.604329e+09  1.544567e+09  1.586179e+09
# 166 2024-04-01  1.769263e+09  1.813210e+09  1.768681e+09  1.812089e+09
# 167 2024-05-01  1.621713e+09  1.643659e+09  1.501827e+09  1.540358e+09
# 168 2024-05-31  1.716635e+09  1.765522e+09  1.705001e+09  1.736676e+09
#
#                volume
# 151   366150278971826
# 152   496990962960149
# 153   578310782337450
# 154   351521871687252
# 155   404259956147681
# 156   546502173098531
# 157   317070650767408
# 158   305766765605510
# 159   227675010457514
# 160   289792703781945
# 161   533416221499074
# 162   394611106650111
# 163   468100533393879
# 164   626784192232643
# 165  1020854317048198
# 166   509354063694000
# 167   961270859973305
# 168   749635227495867

# %%
len(btc)
# Out:
# 18

# %%
stock.quote.history(symbol="TCB", start="2023-01-01", end='2024-12-31')
# Out:
#           time   open   high    low  close   volume
# 0   2023-01-03  24.97  26.62  24.97  26.62  3787630
# 1   2023-01-04  26.62  26.96  26.43  26.48  3186578
# 2   2023-01-05  26.48  26.96  26.33  26.81  2717668
# 3   2023-01-06  26.62  27.54  26.48  26.86  4805646
# 4   2023-01-09  26.96  27.11  26.77  26.91  2388393
# ..         ...    ...    ...    ...    ...      ...
# 345 2024-05-28  46.50  46.95  46.30  46.90  6014900
# 346 2024-05-29  47.00  47.05  46.40  46.50  6948600
# 347 2024-05-30  46.05  46.80  45.85  46.80  7573700
# 348 2024-05-31  46.80  47.00  46.30  47.00  5677200
# 349 2024-06-03  47.50  47.70  47.10  47.50  6467500
#
# [350 rows x 6 columns]

# %%
def get_data(is_stock, symbol, origin_date, end_date, start_date="2023-01-01"):
    try:
        if is_stock:
            df = stock.quote.history(symbol=symbol, start=start_date, end=end_date)
        else:
            symbol_id = MY_ID_MAPPING[symbol]
            quote = Quote(symbol_id=symbol_id)
            df = quote.history(start=start_date, end=end_date, interval='1D')
        origin_close = float(df[df["time"] == origin_date]["close"].iloc[0])
        scale = origin_close / 100
        data = df[["time", "close"]]
        data["close"] = data["close"].div(scale)
        return data[data["time"] >= origin_date]
    except Exception as e:
        print("Error {}: {} {} {}".format(e, symbol, origin_date, end_date))
        return None

# %%
get_data(False, "SPX", "2024-02-01", "2024-06-03")
# Out:
#           time       close
# 271 2024-02-01  100.000000
# 272 2024-02-02  101.068446
# 273 2024-02-05  100.746404
# 274 2024-02-06  100.979171
# 275 2024-02-07  101.811385
# ..         ...         ...
# 350 2024-05-24  108.123004
# 351 2024-05-28  108.149909
# 352 2024-05-29  107.353160
# 353 2024-05-30  106.711725
# 354 2024-05-31  107.568398
#
# [84 rows x 2 columns]

# %%
get_data(True, "TCB", "2024-03-01", "2024-12-31")
# Out:
#           time       close
# 287 2024-03-01  100.000000
# 288 2024-03-04  100.000000
# 289 2024-03-05  100.837645
# 290 2024-03-06  102.143385
# 291 2024-03-07  101.773836
# ..         ...         ...
# 345 2024-05-28  115.545701
# 346 2024-05-29  114.560237
# 347 2024-05-30  115.299335
# 348 2024-05-31  115.792067
# 349 2024-06-03  117.023898
#
# [63 rows x 2 columns]

# %%
# Out:
# c2111
# df           time          open          high           low         close  \
# 151 2023-01-07  4.276969e+08  4.316476e+08  4.246473e+08  4.306309e+08
# 152 2023-02-06  5.927091e+08  5.950255e+08  5.802492e+08  5.831428e+08
# 153 2023-03-08  5.697467e+08  5.722640e+08  5.591521e+08  5.644488e+08
# 154 2023-04-07  7.157353e+08  7.158155e+08  7.046477e+08  7.124053e+08
# 155 2023-05-07  7.503756e+08  7.575207e+08  7.231972e+08  7.342642e+08
# 156 2023-06-06  6.890084e+08  6.891829e+08  6.463836e+08  6.543837e+08
# 157 2023-07-06  7.818720e+08  7.843768e+08  7.678212e+08  7.751514e+08
# 158 2023-08-05  7.411168e+08  7.443607e+08  7.337742e+08  7.385692e+08
# 159 2023-09-04  6.571622e+08  6.626919e+08  6.558301e+08  6.597049e+08
# 160 2023-10-04  6.987921e+08  7.028297e+08  6.913681e+08  6.968038e+08
# 161 2023-11-03  9.003224e+08  9.124718e+08  8.739032e+08  8.875362e+08
# 162 2023-12-03  9.828237e+08  1.007964e+09  9.818919e+08  1.002817e+09
# 163 2024-01-02  1.074045e+09  1.122189e+09  1.072387e+09  1.121983e+09
# 164 2024-02-01  1.090964e+09  1.110553e+09  1.074520e+09  1.081726e+09
# 165 2024-03-02  1.553852e+09  1.604329e+09  1.544567e+09  1.586179e+09
# 166 2024-04-01  1.769263e+09  1.813210e+09  1.768681e+09  1.812089e+09
# 167 2024-05-01  1.621713e+09  1.643659e+09  1.501827e+09  1.540358e+09
# 168 2024-05-31  1.716635e+09  1.765522e+09  1.705001e+09  1.736676e+09
#
#                volume
# 151   366150278971826
# 152   496990962960149
# 153   578310782337450
# 154   351521871687252
# 155   404259956147681
# 156   546502173098531
# 157   317070650767408
# 158   305766765605510
# 159   227675010457514
# 160   289792703781945
# 161   533416221499074
# 162   394611106650111
# 163   468100533393879
# 164   626784192232643
# 165  1020854317048198
# 166   509354063694000
# 167   961270859973305
# 168   749635227495867
# Error single positional indexer is out-of-bounds: BTC 2024-03-01 2024-12-31

# %%
configs = {
    "NGAN_HANG": ["VNINDEX", "VCB", "BID", "CTG", "TCB", "VPB", "MBB", "ACB", "HDB", "VIB", "LPB", "STB"],
    "BAN_LE": ["VNINDEX", "MWG", "FRT", "DGW", "PET", "AST", "DHT"],
    "BAT_DONG_SAN": [
        "VHM",
        "VIC",
        "BCM",
        "VRE",
        "NVL",
        "KDH",
        "SSH",
        "KBC",
        "NLG",
        "TCH",
        "NTL",
    ],
    "TAI_CHINH": [
        "SSI",
        "VND",
        "VCI",
        "HCM",
        "SHS",
        "MBS",
        "VIX",
        "FTS",
        "BSI",
        "EVF",
        "CTS",
        "DSC",
        "BVS",
    ],
    "HANG_CA_NHAN": [
        "PNJ",
        "VGT",
        "TCM",
        "TLG",
        "MSH",
        "RAL",
    ],
    "THUC_PHAM": [
        "VNM",
        "MCH",
        "MSN",
        "SAB",
        "VSF",
        "KDC",
        "QNS",
        "VHC",
        "HAG",
        "BHN",
        "HNG",
        "ANV",
    ],
    "TAI_NGUYEN": [
        "HPG",
        "MSR",
        "HSG",
        "ACG",
        "NKG",
        "KSV",
        "VIF",
        "PTB",
        "TVN",
        "PRT",
    ],
    "XAY_DUNG": [
        "VGC",
        "HUT",
        "CTR",
        "VCG",
        "VCS",
        "BMP",
        "PC1",
        "CTD",
        "SCG",
        "HHV",
        "CII",
    ],
    "DIEN_NUOC_XANG": [
        "GAS",
        "PGV",
        "VSH",
        "POW",
        "BWE",
        "HND",
        "QTP",
        "NT2",
    ],
    "DAU_KHI": [
        "BSR",
        "PLX",
        "PVS",
        "PVD",
        "OIL",
    ],
    "DICH_VU_CONG_NGHIEP": [
        "ACV",
        "VEA",
        "GMD",
        "REE",
        "MVN",
        "GEX",
        "GEE",
        "PVT",
        "VTP",
    ],
    "CONG_NGHE": [
        "FPT",
        "CMG",
        "SAM",
    ],
    "BAO_HIEM": [
        "BVH",
        "PVI",
        "VNR",
        "BIC",
        "MIG",
        "BMI",
        "ABI",
    ],
    "HOA_CHAT": [
        "GVR",
        "DGC",
        "DCM",
        "DPM",
        "PHR",
        "AAA",
    ],
    "OTO_PHU_TUNG":[
        "DRC",
        "HHS",
        "CTF",
        "SVC",
        "CSM",
        "HAX",
    ],
    "DU_LICH": [
        "VJC",
        "SCS",
        "TSJ",
    ],
    "VIEN_THONG": [
        "VGI",
        "FOX",
        "VEF",
        "VNZ"
    ],
    "Y_TE":[
        "DHG",
    "IMP",
    "DVN",
    "DBD",
    ]
}

# %%
def get_data(symbol, origin_date, end_date):
    try:
        df = stock.quote.history(symbol=symbol, start="2023-01-01", end=end_date)
        origin_close = float(df[df["time"] == origin_date]["close"].iloc[0])
        scale = origin_close / 100
        
        data = df[["time", "close"]]
        data["close"] = data["close"].div(scale)
        return data[data["time"] >= origin_date]
    except:
        print("Error: {} {} {}".format(symbol, origin_date, end_date))
        return None

# %%
plt.get_cmap('hsv', 5)

# %%
colors[0:4]

# %%
list(range(10))

# %%
def get_cmap(n, name='hsv'):
    '''Returns a function that maps each index in 0, 1, ..., n-1 to a distinct 
    RGB color; the keyword argument name must be a standard mpl colormap name.'''
    return plt.get_cmap(name, n)

def get_colors(n):
    colors = ["#e2d454", "#26c6da", "#fbc02d", "#673ab7", "#4caf50", "#00bfa5", "#ff5252", "#f48fb1", "#82b1ff", "#00e5ff", "#0048ff", "#1eff00", "#ff6600", "#3a6630", "#305666"]
    if n <= len(colors):
        return colors[0:n]
    
    outputs = list(colors)
    m = n - len(outputs)
    cmap = get_cmap(m)
    for i in range(m):
        outputs.append(cmap(i))
    return outputs

# %%
plt.style.use('dark_background')

list_origin_dates = ["2024-02-01", "2024-03-01", "2024-04-01", "2024-05-02"]
end_date = datetime.now().strftime("%Y-%m-%d")
for (group, tickers) in configs.items():
    ticker_colors = get_colors(len(tickers))
    for idx, origin_date in enumerate(list_origin_dates):
        # file_name = "images/{}_{}.jpg".format(group, idx)
        # if os.path.exists(file_name):
        #     print("Skip {}".format(file_name))
        #     continue
        fig, ax = plt.subplots(figsize=(15, 10))
        ax.set_title("{}_{} - {} to {}".format(group, idx, origin_date, end_date), fontsize=20, weight='bold')
        for ticker_idx, ticker in enumerate(tickers):
            data_ticker = get_data(ticker, origin_date, end_date)
            color = ticker_colors[ticker_idx]
            if data_ticker is None:
                continue
            last_value = data_ticker["close"].iloc[-1]
            label = '{} {:.2f}'.format(ticker, last_value)
            
            data_ticker.plot(ax=ax, x='time', y='close', label=label, color=color)
            ax.annotate(label, xy=(1, last_value), xytext=(10, 0), 
                     xycoords=('axes fraction', 'data'), textcoords='offset points', 
                    color=color, fontsize=15, weight='bold')
        
        # plt.savefig(file_name)
        # print("Saved {}".format(file_name))
        plt.show()
        # plt.close()
        break
    break

# %%
for k in configs.keys():
    print("# {}".format(k))
    for i in range(4):
        n = "{}_{}".format(k, i)
        print("![\"{}\"]({}.jpg)".format(n, n))
